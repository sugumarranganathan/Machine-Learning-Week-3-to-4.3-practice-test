# %%
#Question 1
print(hello world)
# Out:
#   File "/tmp/ipython-input-2497053111.py", line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Answer 1
print("hello world")
# Out:
# hello world

# %%
#Question 2
a = 15
if (a == 15)
    print(a)
# Out:
#   File "/tmp/ipython-input-2895243172.py", line 3
#     if (a == 15)
#                 ^
# SyntaxError: expected ':'

# %%
#Answer 2
a = 15
if a == 15:
    print(a)
# Out:
# 15

# %%
#Question 3
ages ={
    'Sita': 28,
    'Ram': 32
    'Sam': 45
}
print(f'The age of Bob is {ages["Ram"]} years.'
# Out:
#   File "/tmp/ipython-input-386599111.py", line 4
#     'Ram': 32
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Answer 3

ages ={
    'Sita': 28,
    'Ram': 32,
    'Sam': 45
}
print(f'The age of Bob is {ages["Ram"]} years.')
# Out:
# The age of Bob is 32 years.

# %%
#Question 4

def get_shop()
    return [
        "Shop 1",
        "Shop 2",
        "Shop 3"
    ]
# Example of calling the function
result = get_shop()
print(result)
# Out:
#   File "/tmp/ipython-input-853907150.py", line 3
#     def get_shop()
#                   ^
# SyntaxError: expected ':'

# %%
#Answer: 4
def get_shop():
    return [
        "Shop 1",
        "Shop 2",
        "Shop 3"
    ]
# Example of calling the function
result = get_shop()
print(result)
# Out:
# ['Shop 1', 'Shop 2', 'Shop 3']

# %%
#Question 5

numbers = (
    1,
    2,
    3
for num in numbers:
    print(num)
# Out:
#   File "/tmp/ipython-input-3239386415.py", line 3
#     numbers = (
#               ^
# SyntaxError: '(' was never closed

# %%
#Answer: 5

numbers = (
    1,
    2,
    3
)

# Example of using the tuple
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3

# %%
#Question 6

name = "Admin"
if name == "Admin"
    print("Admin will give access.")
else:
    print("Admin will not give access.")
# Out:
#   File "/tmp/ipython-input-95590577.py", line 4
#     if name == "Admin"
#                       ^
# SyntaxError: expected ':'

# %%
#Answer: 6

name = "Admin"
if name == "Admin":
    print("Admin will give access.")
else:
    print("Admin will not give access.")
# Out:
# Admin will give access.

# %%
#Question 7

name = "Admin"

if name = "Admin":
    print("Admin will give access.")
else:
    print("Admin will not give access.")
# Out:
#   File "/tmp/ipython-input-1475693748.py", line 5
#     if name = "Admin":
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#Answer: 7

name = "Admin"

if name == "Admin":
    print("Admin will give access.")
else:
    print("Admin will not give access.")
# Out:
# Admin will give access.

# %%
#Question 8

#Intentional syntax error: Misspelled 'if' and 'else' keywords
user_role = "Admin"

# Misspelled 'if' as 'iif'
iif user_role == "Admin":
    print("Access granted. You are an administrator.")
elsse:
    print("Access denied. You are not an administrator.")
# Out:
#   File "/tmp/ipython-input-1481690619.py", line 7
#     iif user_role == "Admin":
#         ^
# SyntaxError: invalid syntax

# %%
#Answer: 8

# Corrected code
user_role = "Admin"

# Using correct 'if' and 'else' keywords
if user_role == "Admin":
    print("Access granted. You are an administrator.")
else:
    print("Access denied. You are not an administrator.")
# Out:
# Access granted. You are an administrator.

# %%
#Question 9

# Generating squares for numbers 1 to 5
numbers = [1, 2, 3, 4, 5]

# List comprehension to calculate squares
squares = [n**2 for n in numbers

# Printing the result
print(squares)
# Out:
#   File "/tmp/ipython-input-4093622712.py", line 7
#     squares = [n**2 for n in numbers
#               ^
# SyntaxError: '[' was never closed

# %%
#Answer: 9

# Generating squares for numbers 1 to 5
numbers = [1, 2, 3, 4, 5]

# List comprehension to calculate squares
squares = [n**2 for n in numbers]

# Printing the result
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
# 10. Question & Answer


def greet(name):
      print(f"Hello, {name}!")

# Attempting to call the function
greet("Alice")
# Out:
# Hello, Alice!

# %%
# 11. Question

# Intentional syntax errors: Using 'break' and 'continue' outside of loops
persons = ['alice', 'bob', 'charlie']

# Using 'break' outside of a loop
if 'bob' in persons:
    print('Bob found')
    break  # Intentional syntax error

# Using 'continue' outside of a loop
if 'bob' in persons:
    print('Bob found')
    continue  # Intentional syntax error
# Out:
#   File "/tmp/ipython-input-1693631405.py", line 7
#     break  # Intentional syntax error
#     ^
# SyntaxError: 'break' outside loop

# %%
# 11. Answer

# Corrected code: Using 'break' and 'continue' within loops
persons = ['alice', 'bob', 'charlie']

# Using 'break' within a loop
for person in persons:
    if person == 'bob':
        print('Bob found')
        #break  # Exiting the loop when 'bob' is found

# Using 'continue' within a loop
for person in persons:
    if person == 'bob':
        print('Bob found')
        #continue  # Skipping to the next iteration when 'bob' is found
    print(f'Processing {person}')
# Out:
# Bob found
# Processing alice
# Bob found
# Processing bob
# Processing charlie

# %%
# 12. Question

ages = {'pam'; 24}

print(ages['pam'])
# Out:
#   File "/tmp/ipython-input-513614734.py", line 1
#     ages = {'pam'; 24}
#                  ^
# SyntaxError: invalid syntax

# %%
# 12. Answer

# Corrected code
ages = {'pam': 24}

# Output
print(ages['pam'])
# Out:
# 24

# %%
# 13. Question

def count_and_sum():
  total_sum = 0
  for i in range(5):
      total_sum += i
      print(f"Current number: {i}, Running sum: {total_sum}")

    print('Done counting and summing')  # Intentional indentation error

count_and_sum()
# Out:
#   File "<tokenize>", line 7
#     print('Done counting and summing')  # Intentional indentation error
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# 13. Answer

def count_and_sum():
  total_sum = 0
  for i in range(5):
    total_sum += i
    print(f"Current number: {i}, Running sum: {total_sum}")

  print('Done counting and summing')

count_and_sum()
# Out:
# Current number: 0, Running sum: 0
# Current number: 1, Running sum: 1
# Current number: 2, Running sum: 3
# Current number: 3, Running sum: 6
# Current number: 4, Running sum: 10
# Done counting and summing

# %%
# 14. Question
subjects = {'Keera': 'Maths',
            'karthik': 'Biology',
            'naveen': 'Science',
            'Vijay': 'Hindi'}
# Storing the subject of student
# that doesn't exist
sub = subjects.get('Hindi','Student doesn't exist')

print(sub)

# %%
# 14. Answer

subjects = {'Keera': 'Maths',
            'karthik': 'Biology',
            'naveen': 'Science',
            'Vijay': 'Hindi'}
# Storing the subject of student
# that doesn't exist
sub = subjects.get('Vijay',"Student doesn't exist")

print(sub)
# Out:
# Hindi
